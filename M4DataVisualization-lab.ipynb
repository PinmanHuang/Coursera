# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2024-06-18 19:46:52--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104, 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  45.9MB/s    in 0.8s
#
# 2024-06-18 19:46:53 (45.9 MB/s) - ‘m4_survey_data.sqlite’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
query = "SELECT * FROM master"
df = pd.read_sql_query(query, conn)
df.describe()
# Out:
#               index    Respondent     CompTotal  ConvertedComp   WorkWeekHrs  \
# count  11398.000000  11398.000000  1.058900e+04   1.058200e+04  11276.000000
# mean    5698.500000  12490.392437  7.570477e+05   1.315967e+05     42.064606
# std     3290.463519   7235.461999  9.705598e+06   2.947865e+05     24.672741
# min        0.000000      4.000000  0.000000e+00   0.000000e+00      3.000000
# 25%     2849.250000   6264.250000  2.500000e+04   2.686800e+04     40.000000
# 50%     5698.500000  12484.000000  6.500000e+04   5.774500e+04     40.000000
# 75%     8547.750000  18784.750000  1.200000e+05   1.000000e+05     43.000000
# max    11397.000000  25142.000000  7.000000e+08   2.000000e+06   1012.000000
#
#         CodeRevHrs           Age
# count  8972.000000  11111.000000
# mean      4.781071     30.779318
# std       4.567060      7.393680
# min       0.000000     16.000000
# 25%       2.000000     25.000000
# 50%       4.000000     29.000000
# 75%       5.000000     35.000000
# ...

# %%
df_ConvertedComp = df.dropna(subset=['ConvertedComp'])

# %%
# %pip install --upgrade seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
sns.distplot(df_ConvertedComp['ConvertedComp'], kde=False, bins=30)
# sns.histplot(df['ConvertedComp'], kde=False, bins=30)
plt.title('Histogram for ConvertedComp')
plt.xlabel('Converted Compensation')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
df_Age = df.dropna(subset=['Age'])

# %%
# your code goes here
plt.figure(figsize=(10, 6))
sns.boxplot(y=df_Age['Age'])
plt.title('Box Plot of Age')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Age'], y=df['WorkWeekHrs'])
plt.title('Scatter Plot of Age vs WorkWeekHrs')
plt.xlabel('Age')
plt.ylabel('Work Week Hours')
plt.show()

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here

plt.figure(figsize=(10, 6))
bubble_plot = plt.scatter(x=df['WorkWeekHrs'], y=df['CodeRevHrs'], 
                          s=df['Age'], alpha=0.5, c=df['Age'], cmap='viridis')
plt.colorbar(bubble_plot, label='Age')
plt.title('Bubble Plot of WorkWeekHrs vs CodeRevHrs')
plt.xlabel('Work Week Hours')
plt.ylabel('Code Review Hours')
plt.show()

# %%
# normalize Argentina data
norm_age = (df['Age'] - df['Age'].min()) / (df['Age'].max() - df['Age'].min())

# %%
# Brazil
ax0 = df.plot(kind='scatter',
              x='WorkWeekHrs',
              y='CodeRevHrs',
              figsize=(14, 8),
              alpha=0.5,  # transparency
              color='green',
              s=norm_age * 2000 + 10  # pass in weights 
              # xlim=(1975, 2015)
             )

ax0.set_ylabel('Code Review Hours')
ax0.set_title('Bubble Plot of WorkWeekHrs vs CodeRevHrs')
ax0.legend(['Age'], loc='upper right', fontsize='x-large')

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here
query = "SELECT * FROM DatabaseDesireNextYear"
df = pd.read_sql_query(query, conn)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29575 entries, 0 to 29574
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              29575 non-null  int64
#  1   DatabaseDesireNextYear  29575 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 462.2+ KB

# %%
df.head()
# Out:
#    Respondent DatabaseDesireNextYear
# 0           4                  MySQL
# 1           4                 SQLite
# 2           9             PostgreSQL
# 3           9                  Redis
# 4           9                 SQLite

# %%
db_counts = df['DatabaseDesireNextYear'].value_counts()
top_5_dbs = db_counts.head(5)
top_5_dbs
# Out:
# PostgreSQL       4328
# MongoDB          3649
# Redis            3331
# MySQL            3281
# Elasticsearch    2856
# Name: DatabaseDesireNextYear, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.pie(top_5_dbs, labels=top_5_dbs.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 Databases Respondents Wish to Learn Next Year')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
query = "SELECT * FROM LanguageDesireNextYear"
df = pd.read_sql_query(query, conn)
lang_counts = df['LanguageDesireNextYear'].value_counts()
lang_counts.head(10)
# Out:
# JavaScript               6630
# HTML/CSS                 5328
# Python                   5239
# SQL                      5012
# TypeScript               4088
# C#                       3591
# Bash/Shell/PowerShell    3097
# Java                     2953
# Go                       2759
# Kotlin                   1890
# Name: LanguageDesireNextYear, dtype: int64

# %%
query = "SELECT * FROM LanguageWorkedWith"
df = pd.read_sql_query(query, conn)
lang_counts = df['LanguageWorkedWith'].value_counts()
lang_counts.head(10)
# Out:
# JavaScript               8687
# HTML/CSS                 7830
# SQL                      7106
# Bash/Shell/PowerShell    4642
# Python                   4542
# Java                     4506
# C#                       4288
# TypeScript               3232
# PHP                      2913
# C++                      1946
# Name: LanguageWorkedWith, dtype: int64

# %%
query = "SELECT * FROM DatabaseWorkedWith"
df = pd.read_sql_query(query, conn)
df.head()
# Out:
#    Respondent DatabaseWorkedWith
# 0           4              MySQL
# 1           4             SQLite
# 2           9           DynamoDB
# 3           9         PostgreSQL
# 4           9             SQLite

# %%
respondent_db = df.groupby('Respondent')['DatabaseWorkedWith'].apply(list)
mysql_only = respondent_db[respondent_db.apply(lambda x: len(x) == 1 and x[0] == 'MySQL')]
mysql_only.shape
# Out:
# (474,)

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here
query = "SELECT * FROM master"
df = pd.read_sql_query(query, conn)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398 entries, 0 to 11397
# Data columns (total 63 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           11398 non-null  int64
#  1   Respondent      11398 non-null  int64
#  2   MainBranch      11398 non-null  object
#  3   Hobbyist        11398 non-null  object
#  4   OpenSourcer     11398 non-null  object
#  5   OpenSource      11317 non-null  object
#  6   Employment      11398 non-null  object
#  7   Country         11398 non-null  object
#  8   Student         11347 non-null  object
#  9   EdLevel         11286 non-null  object
#  10  UndergradMajor  10661 non-null  object
#  11  OrgSize         11302 non-null  object
#  12  YearsCode       11389 non-null  object
#  13  Age1stCode      11385 non-null  object
#  14  YearsCodePro    11382 non-null  object
#  15  CareerSat       11398 non-null  object
#  16  JobSat          11397 non-null  object
# ...

# %%
df_filtered = df[(df['Age'] >= 30) & (df['Age'] <= 35)]

median_workweekhrs = df_filtered.groupby('Age')['WorkWeekHrs'].median()
median_coderevhrs = df_filtered.groupby('Age')['CodeRevHrs'].median()

median_data = pd.DataFrame({
    'WorkWeekHrs': median_workweekhrs,
    'CodeRevHrs': median_coderevhrs
})

plt.figure(figsize=(10, 6))
median_data.plot(kind='bar', stacked=True, color=['skyblue', 'lightgreen'])
plt.title('Median WorkWeekHrs and CodeRevHrs for Ages 30 to 35')
plt.xlabel('Age')
plt.ylabel('Median Hours')
plt.xticks(rotation=0)
plt.legend(title='Hours')
plt.show()

# %%
df_filtered[['Age', 'WorkWeekHrs', 'CodeRevHrs']].head(10)
# Out:
#      Age  WorkWeekHrs  CodeRevHrs
# 5   31.0          8.0         3.0
# 11  34.0         40.0         2.0
# 12  32.0         40.0         2.0
# 18  34.0         42.0        15.0
# 22  33.0         40.0         2.0
# 23  31.0         40.0         NaN
# 25  34.0         40.0         NaN
# 33  32.0         40.0         2.0
# 41  35.0         38.0         2.0
# 43  30.0         40.0         5.0

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
df_filtered = df[(df['Age'] >= 45) & (df['Age'] <= 60)]
median_converted_comp = df_filtered.groupby('Age')['ConvertedComp'].median()

# Plot the data
plt.figure(figsize=(10, 6))
median_converted_comp.plot(kind='bar', color='skyblue')
plt.title('Median Converted Compensation for Ages 45 to 60')
plt.xlabel('Age')
plt.ylabel('Median Converted Compensation')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
df.head(1)
# Out:
#    index  Respondent                      MainBranch Hobbyist OpenSourcer  \
# 0      0           4  I am a developer by profession       No       Never
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
#
#          Country Student                                   EdLevel  ...  \
# 0  United States      No  Bachelor’s degree (BA, BS, B.Eng., etc.)  ...
#
#                             SOPartFreq SOJobs  \
# 0  Less than once per month or monthly    Yes
#
#                               EntTeams          SOComm  \
# 0  No, and I don't know what those are  No, not really
#
#                              WelcomeChange   Age Trans Dependents  \
# 0  Just as welcome now as I felt last year  22.0    No         No
#
#             SurveyLength SurveyEase
# 0  Appropriate in length       Easy
#
# [1 rows x 63 columns]

# %%
df['Majority'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/conda/envs/python/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Majority'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# your code goes here
mainbranch_counts = df['MainBranch'].value_counts()

plt.figure(figsize=(10, 8))
sns.barplot(x=mainbranch_counts.values, y=mainbranch_counts.index, palette='viridis')
plt.title('Distribution of MainBranch')
plt.xlabel('Count')
plt.ylabel('Main Branch')
plt.show()

# %% [markdown]
# Close the database connection.

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
